# %%
import pandas as pd
import numpy as np

crypto_df = pd.read_csv("https://raw.githubusercontent.com/diljeet1994/Python_Tutorials/master/Projects/Advanced%20ETL/crypto-markets.csv")

# %%
assetCode = ['BTC', 'ETH', 'XRP', 'LTC']

crypto_df['open'] = crypto_df[['open', 'asset']].apply(lambda x: float(x[0])*0.80 if x[1] in assetCode else np.nan, axis = 1)
crypto_df['high'] = crypto_df[['high', 'asset']].apply(lambda x: float(x[0])*0.80 if x[1] in assetCode else np.nan, axis = 1)
crypto_df['low'] = crypto_df[['low', 'asset']].apply(lambda x: float(x[0])*0.80 if x[1] in assetCode else np.nan, axis = 1)
crypto_df['close'] = crypto_df[['close', 'asset']].apply(lambda x: float(x[0])*0.80 if x[1] in assetCode else np.nan, axis = 1)

crypto_df.dropna(inplace= True)
crypto_df.reset_index(drop= True, inplace= True)
try:
    crypto_df.drop(labels=['slug', 'ranknow', 'volume', 'market', 'close_ratio', 'spread'], inplace = True, axis = 1)
except Exception as error:
    print(error)
finally:
    print('Table has dropped')
crypto_df
# Out:
# "['slug' 'ranknow' 'volume' 'market' 'close_ratio' 'spread'] not found in axis"
# Table has dropped
#     asset      name        date      open      high       low     close
# 0     BTC   Bitcoin  28-04-2013  4.760446  4.784371  4.647856  4.722095
# 1     BTC   Bitcoin  29-04-2013  4.730187  5.189343  4.714706  5.085549
# 2     BTC   Bitcoin  30-04-2013  5.066550  5.169640  4.716465  4.890628
# 3     BTC   Bitcoin  01-05-2013  4.890628  4.921942  3.790061  4.116220
# 4     BTC   Bitcoin  02-05-2013  4.094757  4.419157  3.246814  3.701748
# ..    ...       ...         ...       ...       ...       ...       ...
# 490   LTC  Litecoin  09-08-2013  0.095350  0.097109  0.093590  0.094294
# 491   LTC  Litecoin  10-08-2013  0.094646  0.095350  0.090072  0.090072
# 492   LTC  Litecoin  11-08-2013  0.089720  0.095701  0.089016  0.094646
# 493   LTC  Litecoin  12-08-2013  0.094646  0.095701  0.090776  0.093239
# 494   LTC  Litecoin  13-08-2013  0.093590  0.097109  0.092183  0.096405
#
# ...

# %%
import sqlite3 as sql

conn = sql.connect('crypto.db')

try:
    conn.execute('DROP TABLE IF EXISTS Crypto')
except Exception as e:
    print(e)
    
try :
    conn.execute("""
        CREATE TABLE Crypto(
        ID INT PRIMARY KEY,
        Asset TEXT NOT NULL,
        Name TEXT NOT NULL,
        Date DATETIME,
        Open FLOAT DEFAULT 0,
        High FLOAT DEFAULT 0,
        Low FLOAT DEFAULT 0,
        Close FLOAT DEFAULT 0
        );""")
except Exception as e:
    print(e)
    print("Table Creation is Failed")
finally:
    conn.close()

# %%
crypto_list = crypto_df.values.tolist()
conn = sql.connect('crypto.db')
cur = conn.cursor()

try:
    cur.executemany("""
        INSERT INTO Crypto
        (ASSET, NAME, DATE, OPEN, HIGH, LOW, CLOSE)
        VALUES (?, ?, ?, ?, ?, ?, ?)""", crypto_list)
    conn.commit()
    print('Data Inserted Successfully')
except Exception as e:
    print(e)
finally:
    conn.close()
# Out:
# database is locked

# %%
from sqlalchemy import create_engine

engine = create_engine('crypto.db')
query = "TABLE VIEW"
df = pd.read_sql_query(query, engine)
df
# Out:
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\febrian-inspiring\Miniconda3\lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\febrian-inspiring\Miniconda3\lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\febrian-inspiring\Miniconda3\lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\febrian-inspiring\Miniconda3\lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
# ...
